# %%
import pandas as pd

# %%
from google.colab import files
data = files.upload()
# Out:
#      <input type="file" id="files-165eb13a-4f9a-4807-824c-913f5efb640a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-165eb13a-4f9a-4807-824c-913f5efb640a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv('diabetes.csv')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
data.shape
# Out:
# (768, 9)

# %%
data.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.columns[:-1]
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age'],
#       dtype='object')

# %%
X = data[['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age']]

# %%
X
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
data['Outcome'].unique()
# Out:
# array([1, 0])

# %%
y = data[['Outcome']]

# %%
y
# Out:
#      Outcome
# 0          1
# 1          0
# 2          1
# 3          0
# 4          1
# ..       ...
# 763        0
# 764        0
# 765        0
# 766        1
# 767        0
#
# [768 rows x 1 columns]

# %%
from  sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, accuracy_score, f1_score, confusion_matrix

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, y,test_size=0.2, random_state=32)

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.linear_model import Ridge, LinearRegression, LogisticRegression
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# %%
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
 lr = LogisticRegression(penalty='l1', C=0.1, solver='liblinear')

# %%
model_lr = lr.fit(X_train, Y_train)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
y_pred_lr = model_lr.predict(X_test)

# %%
accuracy_lr = accuracy_score(Y_test, y_pred_lr.round())

# %%
accuracy_lr
# Out:
# 0.7922077922077922

# %%
import numpy as np

# %%
def predict():
  user_input = np.array([
      float(input(f'Enter your Pregnancies:')),
      float(input(f'Enter your Glucose:')),
      float(input(f'Enter your BloodPressure:')),
      float(input(f'Enter your SkinThickness:')),
      float(input(f'Enter your Insulin: ')),
      float(input(f'Enter your BMI:')),
      float(input(f'Enter your DiabetesPedigreeFunction:')),
      float(input(f'Enter your Age: '))])
  

  prediction = model_lr.predict(user_input.reshape(1, 8))
                  
  if prediction[0] == 1:
    print('You are liekly to have diabetes')
  else:
    print('You unliekly to have diabetes')  
  return prediction[0]  
predict()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-d09596cfb0e1> in <cell line: 20>()
#      18     print('You unliekly to have diabetes')
#      19   return prediction[0]
# ---> 20 predict()
#
# <ipython-input-32-d09596cfb0e1> in predict()
#       1 def predict():
#       2   user_input = np.array([
# ----> 3       float(input(f'Enter your Pregnancies:')),
#       4       float(input(f'Enter your Glucose:')),
#       5       float(input(f'Enter your BloodPressure:')),
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# ...

# %%
predict()
# Out:
# Enter your Pregnancies:6
# Enter your Glucose:188
# Enter your BloodPressure:80
# Enter your SkinThickness:34
# Enter your Insulin: 23
# Enter your BMI:44
# Enter your DiabetesPedigreeFunction:0.232
# Enter your Age: 28
# You are liekly to have diabetes
# 1

# %%
dt = DecisionTreeRegressor()

# %%
model = dt.fit(X_train, Y_train)

# %%
ypred = model.predict(X_test)

# %%
accuracy = accuracy_score(Y_test, ypred)

# %%
accuracy
# Out:
# 0.7467532467532467

# %%
lr = LinearRegression()
model = lr.fit(X_train, Y_train)
ypred = model.predict(X_test)
accuracy = accuracy_score(Y_test, ypred.round())

# %%
accuracy
# Out:
# 0.7792207792207793

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential([
    layers.Dense(64, activation='relu', input_shape=[X_train.shape[1]]),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train, Y_train, epochs=100, validation_split=0.2)
# Out:
# Epoch 1/100
# 16/16 [==============================] - 1s 11ms/step - loss: 0.6568 - accuracy: 0.6293 - val_loss: 0.6295 - val_accuracy: 0.6829
# Epoch 2/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5544 - accuracy: 0.7352 - val_loss: 0.5926 - val_accuracy: 0.6829
# Epoch 3/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.5053 - accuracy: 0.7617 - val_loss: 0.5680 - val_accuracy: 0.7236
# Epoch 4/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4724 - accuracy: 0.7862 - val_loss: 0.5637 - val_accuracy: 0.7561
# Epoch 5/100
# 16/16 [==============================] - 0s 3ms/step - loss: 0.4547 - accuracy: 0.7963 - val_loss: 0.5650 - val_accuracy: 0.7236
# Epoch 6/100
# 16/16 [==============================] - 0s 4ms/step - loss: 0.4451 - accuracy: 0.7902 - val_loss: 0.5697 - val_accuracy: 0.7398
# Epoch 7/100
# ...

# %%
y_pred = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 2ms/step

# %%
loss, accuracy = model.evaluate(X_test, Y_test)
print('Test accuracy:', accuracy)
# Out:
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6393 - accuracy: 0.7792
# Test accuracy: 0.7792207598686218

# %%
accuracy = accuracy_score(Y_test, y_pred.round())

# %%
accuracy
# Out:
# 0.7792207792207793
